# %%
from keras import Sequential

from keras.layers import SimpleRNN, Dense

# %%
model = Sequential()

model.add(SimpleRNN(3, input_shape =(4,5)))
model.add(Dense(1, activation= "sigmoid"))

model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_16 (SimpleRNN)       │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
shape = model.get_weights()[0].shape
weights_1 = model.get_weights()[0]

print(shape)
print(weights_1)
# Out:
# (5, 3)
# [[ 0.6311199   0.27930146  0.3364585 ]
#  [-0.32111084  0.1427874  -0.37835258]
#  [-0.8274064   0.19721383  0.57042867]
#  [ 0.5981427  -0.36773947  0.71652645]
#  [ 0.03389311  0.3095364   0.09547931]]

# %%
weights_2 = model.get_weights()[1]

print(weights_2)
# Out:
# [[-0.6332396   0.7353415  -0.2414137 ]
#  [ 0.38965178  0.03339446 -0.9203567 ]
#  [-0.66871446 -0.67687356 -0.3076737 ]]

# %%
weights_3 = model.get_weights()[3]

print(weights_3)
# Out:
# [[ 0.16582942]
#  [ 1.1854407 ]
#  [-0.65492004]]
