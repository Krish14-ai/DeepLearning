# %%
import pandas as pd
import keras 
import numpy as np 

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense

# %%
train = pd.read_parquet(r"C:\Users\Krish\Downloads\Deep Learning\Attention_and_encoder_decoder\data\train-00000-of-00001.parquet")
test = pd.read_parquet(r"C:\Users\Krish\Downloads\Deep Learning\Attention_and_encoder_decoder\data\test-00000-of-00001.parquet")
validate = pd.read_parquet(r"C:\Users\Krish\Downloads\Deep Learning\Attention_and_encoder_decoder\data\validation-00000-of-00001.parquet")

# %%
print(train[1:2])
print(test[1:2])
print(validate[1:2])
# Out:
#                                          translation
# 1  {'en': 'Accerciser Accessibility Explorer', 'h...
#                                          translation
# 1  {'en': 'As America's road planners struggle to...
#                                          translation
# 1  {'en': 'With encouragement from Principal Sand...

# %%
sent = train[1:2]
print(sent)
# Out:
#                                          translation
# 1  {'en': 'Accerciser Accessibility Explorer', 'h...

# %%
print(sent.values)
# Out:
# [[{'en': 'Accerciser Accessibility Explorer', 'hi': 'एक्सेर्साइसर पहुंचनीयता अन्वेषक'}]]

# %%
english_sentences = []
hindi_sentences = []

for item in train:
    for pair in item:
        english_sentences.append(pair["en"])
        hindi_sentences.append(pair["hi"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       4 for item in train:
#       5     for pair in item:
# ----> 6         english_sentences.append(pair["en"])
#       7         hindi_sentences.append(pair["hi"])
#
# TypeError: string indices must be integers, not 'str'

# %%
print(train.shape)
print(train.columns)
print(train.head())
# Out:
# (1659083, 1)
# Index(['translation'], dtype='str')
#                                          translation
# 0  {'en': 'Give your application an accessibility...
# 1  {'en': 'Accerciser Accessibility Explorer', 'h...
# 2  {'en': 'The default plugin layout for the bott...
# 3  {'en': 'The default plugin layout for the top ...
# 4  {'en': 'A list of plugins that are disabled by...
